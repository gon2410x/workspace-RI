# %%
from urllib.request import Request, urlopen 
from bs4 import BeautifulSoup 
import scraper

url = 'https://www.infobae.com/economia/'
req = Request(url, headers={'User-Agent': 'Mozilla/5.0'}) 
htlm = urlopen(req).read()
soup = BeautifulSoup(htlm, 'lxml')
anchor = soup.find_all("a", class_="headline-link")


links = []
for link in anchor[0:10]:
    link_noticia= link.get('href')
    links.append('https://www.infobae.com/'+link_noticia)


notices = []
#Obtencion de los datos pedidos
for link in links:
    data_extract = scraper.extractData(link)  
    notices.append(data_extract)


import spacy
import nltk
from nltk.tokenize import word_tokenize 
from nltk.corpus import stopwords
from collections import Counter

text = ''
for notice in notices:
    text += notice['title'] + " "
    text += notice['summary'] + " "
    text += notice['body'] + " "

tokens = word_tokenize(text, language='spanish') 
stop_words = set(stopwords.words('spanish'))
tokens = [token.lower() for token in tokens if token.isalnum() and token.lower() not in stop_words]

frecuencia_tokens = Counter(tokens)
TOP_100 = frecuencia_tokens.most_common(100)

nlp = spacy.load('es_core_news_sm')
textSpacy = ""
for word, frequency in TOP_100:
    textSpacy += word + " "

doc = nlp(textSpacy)
LEMMA = [ L.lemma_ for L in doc]

print("{0:<8} {1:<8} {2:<20} {3}" .format("Ranking","Frequency", "- Word", "- Lemma"))
for i in range(100):
    print(" {0:<8} {1:<8} {2:<20} {3}" .format(i+1, TOP_100[i][1], TOP_100[i][0], LEMMA[i]))
# Out:
# Ranking  Frequency - Word               - Lemma
#  1        31       gas                  gas
#  2        29       pesos                pesos
#  3        23       dólar                dólar
#  4        22       dólares              dólares
#  5        22       precios              precio
#  6        22       millones             millón
#  7        20       mes                  mes
#  8        19       mercado              mercado
#  9        19       país                 país
#  10       19       usd                  usd
#  11       18       banco                banco
#  12       18       fiscal               fiscal
#  13       17       gobierno             gobierno
#  14       17       demanda              demandar
#  15       15       año                  año
#  16       13       suba                 subir
#  17       13       inflación            inflación
#  18       13       argentina            argentino
#  19       13       deuda                deudo
#  20       12       ley                  ley
#  21       12       libre                libre
#  22       12       economía             economía
#  23       12       abril                abril
#  24       12       cepo                 cepo
#  25       12       empresa              empresa
#  26       12       ventas               venta
#  27       11       central              central
#  28       11       bonos                bono
#  29       11       riesgo               riesgo
#  30       11       empresas             empresa
#  31       11       marzo                marzo
#  32       10       tasa                 tasar
#  33       10       puntos               punto
#  34       10       casi                 casi
#  35       10       meses                mes
#  36       10       semana               semana
#  37       10       mayor                mayor
#  38       10       contratos            contrato
#  39       10       interrumpibles       interrumpibl
#  40       9        milei                milei
#  41       9        mayo                 mayo
#  42       9        dos                  dos
#  43       9        baja                 bajo
#  44       9        caída                caída
#  45       9        primer               primero
#  46       9        situación            situación
#  47       9        días                 días
#  48       9        sistema              sistema
#  49       9        productos            productos
#  50       9        carrefour            carrefour
#  51       8        representa           representar
#  52       8        precio               precio
#  53       8        ciento               ciento
#  54       8        reservas             reserva
#  55       8        gnc                  gnc
#  56       8        servicio             servicio
#  57       8        ser                  ser
#  58       8        monetaria            monetario
#  59       7        javier               javier
#  60       7        sigue                seguir
#  61       7        medio                medio
#  62       7        hoy                  hoy
#  63       7        ahora                ahora
#  64       7        2                    2
#  65       7        financieros          financiero
#  66       7        jueves               jueves
#  67       7        nominal              nominal
#  68       7        parte                parte
#  69       7        total                total
#  70       7        anterior             anterior
#  71       7        último               último
#  72       7        frío                 frío
#  73       7        estaciones           estación
#  74       7        distribuidoras       distribuidora
#  75       7        según                según
#  76       7        cortes               corte
#  77       7        carta                carta
#  78       7        transporte           transporte
#  79       7        si                   si
#  80       7        pasivos              pasivo
#  81       7        billones             billón
#  82       7        totales              total
#  83       6        cambiaria            cambiaria
#  84       6        afirmó               afirmar
#  85       6        bases                base
#  86       6        récord               récord
#  87       6        10                   10
#  88       6        mientras             mientras
#  89       6        términos             término
#  90       6        incremento           incremento
#  91       6        9                    9
#  92       6        argentino            argentino
#  93       6        trimestre            trimestre
#  94       6        2024                 2024
#  95       6        abastecimiento       abastecimiento
#  96       6        natural              natural
#  97       6        cortar               cortar
#  98       6        puedan               poder
#  99       6        economista           economista
#  100      6        tener                tener
