# %%
import nltk
import string
from nltk.stem import SnowballStemmer

archivo = open('../assets/texto1.txt', encoding='utf-8', mode='r') #abre el archivo 'texto1.txt' en modo lectura
texto1 = archivo.read()
archivo.close()
#print(texto1)

#convierte el texto a minusculas
texto1 = texto1.lower()


#tokenizacion del texto
textoTokenizado = nltk.tokenize.word_tokenize(texto1) #devuelve el texto separado en palabras (tokens)
textoTokenizado = list(filter(lambda token: token not in string.punctuation, textoTokenizado)) #elimina los signos de puntuacion


#eliminacion de los numeros
listaSinNumeros = []
for palabra in textoTokenizado:
    if palabra.isdigit():
        continue
    else:
        listaSinNumeros.append(palabra)


#eliminacion de las stopwords
stop_words = nltk.corpus.stopwords.words('spanish') #genera la lista de stopwords en espanol

listaSinStopWords = [] #lista las palabras sin stopwords
for palabra in listaSinNumeros:
    if palabra not in stop_words: #si no esta en el listado de stopwords entonces sera guardada en una lista
        listaSinStopWords.append(palabra) #Lista tokenizada sin stopWords

#print('TEXTO SIN STOPWORDS: \n',listaSinStopWords)


#Stemming con el algoritmo snowball
print('{:<18} {:<18}'.format('PALABRA', 'SNOWBALL')) #Se definen 2 columnas para mostrar los datos
print('')
for palabra in listaSinStopWords:
    conSnowball = SnowballStemmer(language='spanish').stem(palabra) #aplicacion de stemming con snowball

    print("{:<18} {:<18}".format(palabra, conSnowball))
# Out:
# PALABRA            SNOWBALL
#
# sistemas           sistem
# recomendadores     recomend
# herramientas       herramient
# enfocadas          enfoc
# ayudar             ayud
# usuarios           usuari
# obtener            obten
# aquella            aquell
# información        inform
# mejor              mejor
# corresponda        correspond
# intereses          interes
# preferencias       preferent
# mientras           mientr
# buscador           buscador
# habitual           habitual
# centra             centr
# encontrar          encontr
# aquello            aquell
# usuario            usuari
# solicita           solicit
# sistema            sistem
# recomendador       recomend
# ayuda              ayud
# usuario            usuari
# tomar              tom
# decisión           decision
# puede              pued
# ser                ser
# compra             compr
# producto           product
# portal             portal
# comercio           comerci
# electrónico        electron
# lectura            lectur
# libro              libr
# revisión           revision
# artículo           articul
# científico         cientif
# acceso             acces
# página             pagin
# web                web
# específico         especif
# estudio            estudi
# determinado        determin
# recurso            recurs
# educativo          educ
# plataforma         plataform
# virtual            virtual
# aprendizaje        aprendizaj
# clasificación      clasif
# popular            popul
# sistemas           sistem
# recomendadores     recomend
# asociada           asoci
# algoritmo          algoritm
# emplean            emple
# realizar           realiz
# tarea              tare
# minería            min
# correspondiente    correspondient
# divide             divid
# métodos            metod
# recomendación      recomend
# métodos            metod
# filtrado           filtr
# basado             bas
# contenido          conten
# métodos            metod
# filtrado           filtr
# colaborativo       colabor
# métodos            metod
# filtrado           filtr
# demográfico        demograf
# métodos            metod
# híbridos           hibr
# 1-4                1-4
# adición            adicion
# literatura         literatur
# desarrollado       desarroll
# sistemas           sistem
# recomendadores     recomend
# sugerencia         sugerent
# ítems              items
# usuarios           usuari
# individuales       individual
# enfocados          enfoc
# grupos             grup
# usuarios           usuari
# así                asi
# sistemas           sistem
# recomendadores     recomend
# enfocados          enfoc
# grupos             grup
# usuarios           usuari
# centran            centr
# sugerencia         sugerent
# determinados       determin
# tipos              tip
# ítems              items
# tienden            tiend
# ser                ser
# consumidos         consum
# grupos             grup
# usuarios           usuari
# individuales       individual
# tales              tal
# programas          program
# televisión         television
# paquetes           paquet
# turísticos         turist
# manera             maner
# general            general
# dominios           domini
# iniciales          inicial
# aplicación         aplic
# sistemas           sistem
# recomendadores     recomend
# sido               sid
# e-commerce         e-commerc
# e-learning         e-learning
# aunque             aunqu
# últimos            ultim
# tiempos            tiemp
# sistemas           sistem
# siendo             siend
# aplicados          aplic
# escenarios         escenari
# cada               cad
# vez                vez
# diversos           divers
# así                asi
# relevantes         relev
# aplicaciones       aplic
# sistemas           sistem
# recomendadores     recomend
# escenarios         escenari
# e-health           e-health
# e-tourism          e-tourism
# dos                dos
# contextos          context
# relevantes         relev
# particular         particul
# importancia        import
# específicamente    especif
# resulta            result
# importante         import
# últimos            ultim
# años               años
# desarrollo         desarroll
# sistemas           sistem
# recomendadores     recomend
# dominio            domini
# turismo            turism
# dominio            domini
# existe             exist
# mucha              much
# información        inform
# línea              line
# disponible         dispon
# sistemas           sistem
# recomendadores     recomend
# juegan             jueg
# papel              papel
# importante         import
# vistas             vist
# ayudar             ayud
# usuarios           usuari
# toma               tom
# decisiones         decision
# paquete            paquet
# turístico          turist
# comprar            compr
# instalación        instal
# hotelera           hoteler
# visitar            visit
# recorrido          recorr
# turístico          turist
# elegir             eleg
# decisiones         decision
# similares          similar
# tomar              tom
# vistas             vist
# lograr             logr
# satisfacción       satisfaccion
# final              final
# cliente            client
